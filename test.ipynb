# %%
import pandas as pd

# %%
df=pd.read_csv('artifacts\data_transformation\\train.csv')

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196833 entries, 0 to 196832
# Data columns (total 252 columns):
#  #    Column                 Dtype
# ---   ------                 -----
#  0    sensor_0_avg           float64
#  1    sensor_0_max           float64
#  2    sensor_0_min           float64
#  3    sensor_0_std           float64
#  4    sensor_1_avg           float64
#  5    sensor_1_max           float64
#  6    sensor_1_min           float64
#  7    sensor_1_std           float64
#  8    sensor_2_avg           float64
#  9    sensor_2_max           float64
#  10   sensor_2_min           float64
#  11   sensor_2_std           float64
#  12   sensor_3_avg           float64
#  13   sensor_3_max           float64
#  14   sensor_3_min           float64
#  15   sensor_3_std           float64
#  16   sensor_4_avg           float64
#  17   sensor_4_max           float64
#  18   sensor_4_min           float64
#  19   sensor_4_std           float64
# ...

# %%
df.shape
# Out:
# (196833, 252)
